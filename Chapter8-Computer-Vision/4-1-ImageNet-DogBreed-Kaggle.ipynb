# %% [markdown]
# # <font color="green">使用``Gluon``识别ImageNet子集 - 120种狗
#
# <img src="../img/Chapter8-Computer-Vision/8-2.png" width="1000">
#
# 比赛地址：[Dog Breed Identification](https://www.kaggle.com/c/dog-breed-identification)
#
# ** 学会使用kaggle官方工具下载数据集：**
#
# github地址： https://github.com/Angzz/kaggle-api
# * 1.pip install kaggle
# * 2.在kaggle个人用户界面授权获得API文件 - kaggle.json
# * 3.将kaggle.json上传至/home/<username>/.kaggle目录下
# * 4.授权访问： chmod 600 /home/liang/.kaggle/kaggle.json
# * 5.下载数据集：kaggle competitions download -c favorita-grocery-sales-forecasting -f test.csv.7z

# %%
import mxnet as mx
import numpy as np
import pandas as pd

import utils

from mxnet import nd
from mxnet import gluon
from mxnet import autograd
from mxnet import image
from mxnet import lr_scheduler

from tqdm import tqdm

# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 120
import matplotlib.pyplot as plt

mx.random.seed(2018)

# %% [markdown]
# ## 解压数据文件

# %%
data_dir = "data/kaggle_dog"
train_file = 'train.zip'
test_file = 'test.zip'
label_file = 'labels.csv.zip'

zipfiles = [train_file, test_file, label_file]
import os
import zipfile

# just execute once 
if not os.path.exists(data_dir+'/'+'train') and not os.path.exists(data_dir+'/'+'test'):
    for file in zipfiles:
        with zipfile.ZipFile(data_dir + '/' + file, 'r') as zin:
            zin.extractall(data_dir)

# %% [markdown]
# ## 整理数据集

# %%
from collections import Counter
# Python内置模块Counter计数器的使用
s = '''A Counter is a dict subclass for counting hashable objects. It is an unordered collection where elements 
are stored as dictionary keys and their counts are stored as dictionary values. Counts are allowed to be any 
integer value including zero or negative counts. The Counter class is similar to bags or multisets in other 
languages.'''.lower()

c = Counter(s)
c.most_common
# Out:
# <bound method Counter.most_common of Counter({' ': 54, 'e': 32, 's': 25, 'a': 24, 't': 24, 'o': 22, 'n': 21, 'r': 20, 'i': 20, 'c': 15, 'l': 14, 'u': 13, 'd': 10, 'g': 7, 'h': 6, 'b': 5, '.': 4, 'y': 4, 'm': 3, '\n': 3, 'v': 3, 'w': 2, 'f': 1, 'j': 1, 'k': 1, 'z': 1})>

# %%
import math
import shutil
from collections import Counter

def reorg_dog_files(data_dir, label_file, train_dir, test_dir, input_dir, valid_ratio):
    # 整理label
    with open(os.path.join(data_dir, label_file)) as f:
        lines = f.readlines()[1:]
        tokens = [l.rstrip().split(',') for l in lines]
        # use generator to generate the dictionary
        idx_label = dict(((idx, label) for idx, label in tokens))
        labels = set(idx_label.values())
    
    # 训练集的数量
    num_train = len(os.listdir(os.path.join(data_dir, train_dir)))
    # 训练集中数量最少的狗品种
    min_num_train_per_label = Counter(idx_label.values()).most_common()[::-1][0][1]
    # 设置验证集中每一类狗的数量
    num_valid_per_label = math.floor(min_num_train_per_label * valid_ratio)
    
    def make_dir_if_not_exist(path):
        if not os.path.exists(os.path.join(*path)):
            os.makedirs(os.path.join(*path))
    
    label_count = {}
    # 整理训练和验证集
    for train_file in os.listdir(os.path.join(data_dir, train_dir)):
        idx = train_file.split('.')[0]
        label = idx_label[idx]
        make_dir_if_not_exist([data_dir, input_dir, 'train_valid', label])
        shutil.copy(os.path.join(data_dir, train_dir, train_file), 
                   os.path.join(data_dir, input_dir, 'train_valid', label))
        if label not in label_count or label_count[label] < num_valid_per_label:
            make_dir_if_not_exist([data_dir, input_dir, 'valid', label])
            shutil.copy(os.path.join(data_dir, train_dir, train_file),
                       os.path.join(data_dir, input_dir, 'valid', label))
            label_count[label] = label_count.get(label, 0) + 1
        else:
            make_dir_if_not_exist([data_dir, input_dir, 'train', label])
            shutil.copy(os.path.join(data_dir, train_dir, train_file),
                       os.path.join(data_dir, input_dir, 'train', label))
    
    # 整理测试集
    for test_file in os.listdir(os.path.join(data_dir, test_dir)):
        make_dir_if_not_exist([data_dir, input_dir, 'test', 'unknown'])
        shutil.copy(os.path.join(data_dir, test_dir, test_file),
                   os.path.join(data_dir, input_dir, 'test', 'unknown'))

# %%
unzipfiles = [zip.split('.')[0] for zip in zipfiles[:-1]]
unzipfiles.append('labels.csv')

data_dir = 'data/kaggle_dog'
input_dir = 'train_valid_test'
train_dir, test_dir, label_file = unzipfiles
valid_ratio = 0.1
valid_dir = 'valid'
train_valid_dir = 'train_valid'

model_features_dir = 'model_features'
nd_data_dir = 'nd_data'

if not os.path.exists(os.path.join(data_dir, input_dir, test_dir)):
    reorg_dog_files(data_dir, label_file=label_file, train_dir=train_dir, test_dir=test_dir, 
                    input_dir=input_dir, valid_ratio=0.1)

# %% [markdown]
# ## 使用``Gluon``读取数据集

# %%
def apply_aug_list(img, augs):
    for aug in augs:
        img = aug(img)
    return aug

def get_transform(augs):
    def transform(data, label):
        data = data.astype(np.float32)
        for aug in augs:
            data = aug(data)
        # 是否使用clip有待商榷
        data = data.transpose((2,0,1)) / 255
        return data, nd.array([label]).asscalar().astype(np.float32)
    return transform

input_str = data_dir + '/' + input_dir + '/'

# Load to DataLoader
def get_data(inceptionv3=False, batch_size=64, get_ds=False):
    resize = 299 if inceptionv3 else 224
    train_augs = [
        image.ForceResizeAug((resize, resize)),
        image.ColorNormalizeAug(mean=nd.array([0.485, 0.456, 0.406]), std=nd.array([0.229, 0.224, 0.225]))
    ]

    test_augs = [
        image.ForceResizeAug((resize, resize)),
        image.ColorNormalizeAug(mean=nd.array([0.485, 0.456, 0.406]),
                               std=nd.array([0.229, 0.224, 0.225]))
    ]
    
    train_ds = gluon.data.vision.ImageFolderDataset(input_str + train_dir, transform=get_transform(train_augs))
    valid_ds = gluon.data.vision.ImageFolderDataset(input_str + valid_dir, transform=get_transform(test_augs))
    train_valid_ds = gluon.data.vision.ImageFolderDataset(input_str + train_valid_dir, transform=get_transform(train_augs))
    test_ds = gluon.data.vision.ImageFolderDataset(input_str + test_dir, transform=get_transform(test_augs))
    if get_ds:
        return train_ds, valid_ds, train_valid_ds, test_ds
    train_data = gluon.data.DataLoader(train_ds, batch_size=batch_size, shuffle=True, last_batch='keep')
    valid_data = gluon.data.DataLoader(valid_ds, batch_size=batch_size, shuffle=True, last_batch='keep')
    train_valid_data = gluon.data.DataLoader(train_valid_ds, batch_size=batch_size, shuffle=True, last_batch='keep')
    test_data = gluon.data.DataLoader(test_ds, batch_size=batch_size, shuffle=False, last_batch='keep')
    return train_data, valid_data, train_valid_data, test_data

# %% [markdown]
# ## 画出图片

# %%
train_data, _, _, _ = get_data(inceptionv3=False)
for img, _ in train_data:
    img = img.as_in_context(mx.cpu())
    break
utils.show_images(img.transpose((0,2,3,1)), nrows=8, ncols=8, figsize=(6,6))

# %% [markdown]
# ## 使用预训练模型进行迁移学习
#
# 使用迁移学习的好处是：由于在ImageNet上训练过的模型具有很强的模型泛化能力，因此我们可以用预训练的模型来解决新的任务，一般的做法是，我们固定模型的feature层，将所有数据划分后过一遍feature层并保存模型特征，最后使用一个全连接的网络对预训练模型的输出进行分类，这样既保留了ImageNet上模型强大的表达能力，又可以节约计算资源，因为我们仅需要将模型过一遍全连接层，而预训练阶段因为没有反向传播过程，因此很快就可以由输入得到输出。

# %% [markdown]
# ###  保存数据标签至本地
# * 注意数据顺序只能如下，不能变

# %%
# 将特征保存到本地之后就不需要再初始化数据了
train_data_224, valid_data_224, _, _ = get_data(inceptionv3=False, get_ds=True)
train_data_299, valid_data_299, _, _ = get_data(inceptionv3=True, get_ds=True)

batch_size = 32
# 这边不shuffle的原因是为了保持生成的224尺寸的数据和299尺寸的数据顺序是相同的
train_iter_224 = gluon.data.DataLoader(train_data_224, batch_size=batch_size, shuffle=False, last_batch='keep')
train_iter_299 = gluon.data.DataLoader(train_data_299, batch_size=batch_size, shuffle=False, last_batch='keep')
valid_iter_224 = gluon.data.DataLoader(valid_data_224, batch_size=batch_size, shuffle=False, last_batch='keep')
valid_iter_299 = gluon.data.DataLoader(valid_data_299, batch_size=batch_size, shuffle=False, last_batch='keep')

# %% [markdown]
# ### 定义保存所有预训练模型特征的函数并导出所有预训练模型的特征

# %%
from mxnet.gluon.model_zoo import vision as models

ctx_list = [mx.gpu()]

# 保存预训练模型的features到本地
def save_features(model_name, train_iter, valid_iter, ignore=False):
    # 判断features是否已存在
    if not os.path.exists(os.path.join(data_dir, model_features_dir)):
        os.mkdir(os.path.join(data_dir, model_features_dir)) 
    if os.path.exists(os.path.join(data_dir, model_features_dir, 'features_train_{}.nd'.format(model_name))) and ignore:
        if os.path.exists(os.path.join(data_dir, model_features_dir, 'features_test_{}.nd'.format(model_name))):
            return 
        
    print('--------------------%s--------------------' % (model_name))
    net = models.get_model(model_name, pretrained=True, ctx=ctx_list)
    global_avg_pool = gluon.nn.GlobalAvgPool2D()
    flatten = gluon.nn.Flatten()
    for prefix, data_iter in zip(['train', 'valid'], [train_iter, valid_iter]):
        features = []
        labels = []
        for data, label in tqdm(data_iter):
            # 使用split_and_load进行多设备预测
            data_batch = gluon.utils.split_and_load(data, ctx_list=ctx_list, even_split=False)
            for data_slice in data_batch:
                feature = net.features(data_slice)
                if 'squeezenet' in model_name:
                    feature = global_avg_pool(feature)
                # 这地方到底要不要加flatten有待商榷
                feature = flatten(feature)
                # 将所有特征都保存到cpu
                features.append(feature.as_in_context(mx.cpu()))      
            nd.waitall()
            labels.append(label)
        features = nd.concat(*features, dim=0)
        labels = nd.concat(*labels, dim=0)
        nd.save(os.path.join(data_dir, model_features_dir, 'features_{}_{}.nd'.format(prefix, model_name)), [features, labels])

# %% [markdown]
# ### 加载预训练模型并保存所有模型特征

# %%
from mxnet.gluon.model_zoo.model_store import _model_sha1

# 保存所有模型的特征
# for model in sorted(_model_sha1.keys()):
#     print(model)
model = 'resnet152_v1'
if model == 'inceptionv3':
    save_features(model, train_iter_299, valid_iter_299, ignore=True)
else:
    save_features(model, train_iter_224, valid_iter_224, ignore=True)

# %% [markdown]
# ### 使用所有导出的特征进行训练，并比较模型性能，挑选出最佳模型进行Ensemble
# * 即选出valid_loss最小的前n个网络进行训练
#
# #### 定义输出网络

# %%
num_classes = 120

def output_model(ctx):
    output = gluon.nn.HybridSequential()
    with output.name_scope():
        output.add(
            gluon.nn.Dense(256),
            gluon.nn.Activation('relu'),
            gluon.nn.Dropout(rate=.5),
            gluon.nn.Dense(num_classes)
        )
    output.collect_params().initialize(ctx=ctx, init=mx.init.Xavier(rnd_type='gaussian', factor_type='in', magnitude=2.))
    output.hybridize()
    return output

# %% [markdown]
# #### 从本地加载预训练模型输出的特征，划分训练集和验证集

# %%
def load_traindata_from_pretrained_models(model_name, inceptionv3=False, batch_size=128):
    train_feature_label = nd.load(os.path.join(data_dir,  model_features_dir, 'features_train_{}.nd'.format(model_name)))
    valid_feature_label = nd.load(os.path.join(data_dir,  model_features_dir, 'features_valid_{}.nd'.format(model_name)))
    train_len = int(train_feature_label[0].shape[0])
    valid_len = int(valid_feature_label[0].shape[0])
    train_iter = gluon.data.DataLoader(gluon.data.ArrayDataset(train_feature_label[0], train_feature_label[1]),
                                       batch_size=batch_size, shuffle=True, last_batch='keep')
    valid_iter = gluon.data.DataLoader(gluon.data.ArrayDataset(valid_feature_label[0], valid_feature_label[1]),
                                       batch_size=batch_size, shuffle=False, last_batch='keep')
    return train_iter, valid_iter

# %% [markdown]
# #### 训练预训练模型进行性能评估，并按照valid_loss排序

# %%
from time import time
    
def train_pretrained_models(model_name, epochs=50, batch_size=128, learning_rate=1e-4, wd=1e-5, ctx=mx.gpu()):
    train_iter, valid_iter = load_traindata_from_pretrained_models(model_name, batch_size)
    net = output_model(ctx)
    trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': learning_rate, 'wd': wd})
    softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
    
    moving_loss = .0
    smooth_const = .9
    niter = 0
    
    print('--------------------%s--------------------' % (model_name))
    for epoch in range(epochs):
        start = time()
        for i, (data, label) in enumerate(train_iter):
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            with autograd.record():
                output = net(data)
                loss = softmax_cross_entropy(output, label)
            loss.backward()
            trainer.step(batch_size)
            
            niter += 1
            curr_loss = nd.mean(loss).asscalar()
            moving_loss = smooth_const * moving_loss + (1-smooth_const) *  curr_loss
            estimated_loss = moving_loss / (1 - smooth_const**niter)
            
        train_acc, train_loss = utils.evaluate_accuracy_gluon(train_iter, net, ctx, loss_avg=True)
        valid_acc, valid_loss = utils.evaluate_accuracy_gluon(valid_iter, net, ctx, loss_avg=True)
            
        if not (epoch+1) % 5:
            print("[Epoch %d] Moving Train Loss %.5f, Train Acc %.5f, Valid Loss %.5f, Valid Acc %.5f, Time Consume %.5f s."
                 % (epoch+1, estimated_loss, train_acc, valid_loss, valid_acc, time()-start))
    return valid_loss

# %%
ctx = mx.gpu()
valid_losses = {}
# for model_name in sorted(_model_sha1.keys()):
model_name = 'inceptionv3'
final_valid_loss = train_pretrained_models(model_name)
valid_losses[model_name] = final_valid_loss

# %%
valid_losses
# Out:
# {'inceptionv3': 0.8482408026854198}

# %%
# df = pd.DataFrame(valid_losses, columns=['model', 'val_loss'])
# df = df.sort_values('val_loss')
# df.head()

# %% [markdown]
# ### 保存测试集的模型特征

# %%
resize = 224
test_augs = [
    image.ForceResizeAug((resize, resize)),
    image.ColorNormalizeAug(mean=nd.array([0.485, 0.456, 0.406]),
                           std=nd.array([0.229, 0.224, 0.225]))
]
test_batch_size = 32
test_ds_224 = gluon.data.vision.ImageFolderDataset(input_str + test_dir, transform=get_transform(test_augs))
test_data_224 = gluon.data.DataLoader(test_ds_224, batch_size=test_batch_size, shuffle=False, last_batch='keep')

# %%
resize = 299
test_augs = [
    image.ForceResizeAug((resize, resize)),
    image.ColorNormalizeAug(mean=nd.array([0.485, 0.456, 0.406]),
                           std=nd.array([0.229, 0.224, 0.225]))
]
test_batch_size = 32
test_ds_299 = gluon.data.vision.ImageFolderDataset(input_str + test_dir, transform=get_transform(test_augs))
test_data_299 = gluon.data.DataLoader(test_ds_299, batch_size=test_batch_size, shuffle=False, last_batch='keep')

# %%
# 画出几张图片看看顺序
for img, _ in test_data_299:
    img = img.as_in_context(mx.cpu())
    break
utils.show_images(img.transpose((0,2,3,1)), nrows=4, ncols=4, figsize=(10,10))
# 可以看见该顺序与sample_submission.csv中的顺序是一致的

# %%
def save_test_features(model_name, test_iter):
    # 判断features是否存在
    if not os.path.exists(os.path.join(data_dir, model_features_dir)):
        os.mkdir(os.path.join(data_dir, model_features_dir))
    if os.path.exists(os.path.join(data_dir, model_features_dir, 'features_test_{}.nd'.format(model_name))):
        return
    print('-----------------------{}-----------------------'.format(model_name))
    net = models.get_model(model_name, pretrained=True, ctx=ctx_list)
    global_avg_pool = gluon.nn.GlobalAvgPool2D()
    flatten = gluon.nn.Flatten()
    prefix, data_iter = 'test', test_iter
    features = []
    labels = []
    for data, label in tqdm(data_iter):
        data_batch = gluon.utils.split_and_load(data, ctx_list=ctx_list, even_split=False)
        for data_slice in data_batch:
            feature = net.features(data_slice)
            if 'squeezenet' in model_name:
                feature = global_avg_pool(feature)
            feature = flatten(feature)
            features.append(feature.as_in_context(mx.cpu()))
        nd.waitall()
        labels.append(label)
    features = nd.concat(*features, dim=0)
    labels = nd.concat(*labels, dim=0)
    nd.save(os.path.join(data_dir, model_features_dir, 'features_{}_{}.nd'.format(prefix, model_name)), [features, labels])

# %%
# for model in sorted(_model_sha1.keys()):
model = 'inceptionv3'
if model == 'inceptionv3':
    save_test_features(model, test_data_299)
else:
    save_test_features(model, test_data_224)

# %% [markdown]
# ### 挑选效果最好的模型进行训练

# %%
# ensemble所有的features
###################################  2018年3月5日
def load_traindata_from_ensemble_pretrained_models(model_names, batch_size=128):
    ensemble_train_feature_label = [nd.load(os.path.join(data_dir, model_features_dir, 'features_train_{}.nd'.format(model_name)))[0] for model_name in model_names]
    ensemble_valid_feature_label = [nd.load(os.path.join(data_dir, model_features_dir, 'features_valid_{}.nd'.format(model_name)))[0] for model_name in model_names]
    # 想想这里为什么是dim=1
    ensemble_train_feature = nd.concat(*ensemble_train_feature_label, dim=1)
    ensemble_valid_feature = nd.concat(*ensemble_valid_feature_label, dim=1)
    
    train_label = nd.load(os.path.join(data_dir, model_features_dir, 'features_train_{}.nd'.format(model_names[0])))[1]
    valid_label = nd.load(os.path.join(data_dir, model_features_dir, 'features_valid_{}.nd'.format(model_names[0])))[1]
    
    train_iter = gluon.data.DataLoader(gluon.data.ArrayDataset(ensemble_train_feature, train_label),
                                       batch_size=batch_size, shuffle=True, last_batch='keep')
    valid_iter = gluon.data.DataLoader(gluon.data.ArrayDataset(ensemble_valid_feature, valid_label),
                                       batch_size=batch_size, shuffle=False, last_batch='keep')
    return train_iter, valid_iter

# %%
classifier_net = output_model(ctx=mx.gpu())

def train_ensemble_pretrained_models(net, model_names, epochs=100, batch_size=128, lr=1e-4, wd=1e-5, ctx=mx.gpu()):
    train_iter, valid_iter = load_traindata_from_ensemble_pretrained_models(model_names)
    lr_sch = mx.lr_scheduler.FactorScheduler(step=400, factor=0.9)
    trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': lr, 'wd': wd, 'lr_scheduler': lr_sch})
    softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()
    
    moving_loss = .0
    smooth_const = .9
    niter = 0
    
    print('--------------------%s--------------------' % (model_names))
    for epoch in range(epochs):
        start = time()
        for i, (data, label) in enumerate(train_iter):
            data = data.as_in_context(ctx)
            label = label.as_in_context(ctx)
            with autograd.record():
                output = net(data)
                loss = softmax_cross_entropy(output, label)
            loss.backward()
            trainer.step(batch_size)
            
            niter += 1
            curr_loss = nd.mean(loss).asscalar()
            moving_loss = smooth_const * moving_loss + (1-smooth_const) *  curr_loss
            estimated_loss = moving_loss / (1 - smooth_const**niter)
            
        train_acc, train_loss = utils.evaluate_accuracy_gluon(train_iter, net, ctx, loss_avg=True)
        valid_acc, valid_loss = utils.evaluate_accuracy_gluon(valid_iter, net, ctx, loss_avg=True)
            
        print("[Epoch %d] Moving Train Loss %.5f, Train Acc %.5f, Valid Loss %.5f, Valid Acc %.5f, Time Consume %.5f s.lr: %.5f"
                 % (epoch+1, estimated_loss, train_acc, valid_loss, valid_acc, time()-start, trainer.learning_rate))
    return valid_loss

# %%
model_names = ['inceptionv3', 'resnet152_v1']
train_ensemble_pretrained_models(classifier_net, model_names)
# Out:
# --------------------['inceptionv3', 'resnet152_v1']--------------------
# [Epoch 1] Moving Train Loss 4.30859, Train Acc 0.25005, Valid Loss 4.04576, Valid Acc 0.21667, Time Consume 3.49400 s.lr: 0.00010
# [Epoch 2] Moving Train Loss 3.39939, Train Acc 0.52126, Valid Loss 2.99628, Valid Acc 0.48472, Time Consume 3.59900 s.lr: 0.00010
# [Epoch 3] Moving Train Loss 2.62440, Train Acc 0.65755, Valid Loss 2.18806, Valid Acc 0.60417, Time Consume 3.65000 s.lr: 0.00010
# [Epoch 4] Moving Train Loss 2.28317, Train Acc 0.72511, Valid Loss 1.69752, Valid Acc 0.69028, Time Consume 2.69500 s.lr: 0.00010
# [Epoch 5] Moving Train Loss 1.84289, Train Acc 0.76815, Valid Loss 1.40809, Valid Acc 0.72500, Time Consume 2.85300 s.lr: 0.00010
# [Epoch 6] Moving Train Loss 1.59943, Train Acc 0.79183, Valid Loss 1.22927, Valid Acc 0.73194, Time Consume 3.08000 s.lr: 0.00009
# [Epoch 7] Moving Train Loss 1.44801, Train Acc 0.80383, Valid Loss 1.14066, Valid Acc 0.75278, Time Consume 3.41800 s.lr: 0.00009
# [Epoch 8] Moving Train Loss 1.39912, Train Acc 0.81920, Valid Loss 1.06826, Valid Acc 0.74861, Time Consume 2.93500 s.lr: 0.00009
# [Epoch 9] Moving Train Loss 1.26837, Train Acc 0.83046, Valid Loss 1.01035, Valid Acc 0.75556, Time Consume 2.79500 s.lr: 0.00009
# [Epoch 10] Moving Train Loss 1.27843, Train Acc 0.84119, Valid Loss 0.96154, Valid Acc 0.76944, Time Consume 2.69300 s.lr: 0.00009
# [Epoch 11] Moving Train Loss 1.17151, Train Acc 0.84572, Valid Loss 0.92563, Valid Acc 0.76667, Time Consume 2.87500 s.lr: 0.00008
# [Epoch 12] Moving Train Loss 1.16765, Train Acc 0.85119, Valid Loss 0.91384, Valid Acc 0.77222, Time Consume 3.19200 s.lr: 0.00008
# [Epoch 13] Moving Train Loss 1.07340, Train Acc 0.86066, Valid Loss 0.89468, Valid Acc 0.76667, Time Consume 2.89100 s.lr: 0.00008
# [Epoch 14] Moving Train Loss 1.02411, Train Acc 0.86582, Valid Loss 0.87035, Valid Acc 0.77222, Time Consume 2.86400 s.lr: 0.00008
# [Epoch 15] Moving Train Loss 1.01724, Train Acc 0.86824, Valid Loss 0.85256, Valid Acc 0.77500, Time Consume 3.83700 s.lr: 0.00008
# [Epoch 16] Moving Train Loss 0.96510, Train Acc 0.87340, Valid Loss 0.84328, Valid Acc 0.77222, Time Consume 3.19400 s.lr: 0.00008
# [Epoch 17] Moving Train Loss 0.96174, Train Acc 0.87824, Valid Loss 0.82662, Valid Acc 0.77778, Time Consume 2.80600 s.lr: 0.00007
# [Epoch 18] Moving Train Loss 0.92640, Train Acc 0.88255, Valid Loss 0.81186, Valid Acc 0.78750, Time Consume 2.77400 s.lr: 0.00007
# [Epoch 19] Moving Train Loss 0.87763, Train Acc 0.88655, Valid Loss 0.81097, Valid Acc 0.78472, Time Consume 2.71900 s.lr: 0.00007
# [Epoch 20] Moving Train Loss 0.87956, Train Acc 0.88908, Valid Loss 0.79984, Valid Acc 0.78472, Time Consume 2.67200 s.lr: 0.00007
# [Epoch 21] Moving Train Loss 0.83383, Train Acc 0.89213, Valid Loss 0.78380, Valid Acc 0.78056, Time Consume 2.66000 s.lr: 0.00007
# [Epoch 22] Moving Train Loss 0.78523, Train Acc 0.89760, Valid Loss 0.78705, Valid Acc 0.78889, Time Consume 2.68000 s.lr: 0.00007
# [Epoch 23] Moving Train Loss 0.76649, Train Acc 0.90339, Valid Loss 0.77586, Valid Acc 0.79028, Time Consume 2.67800 s.lr: 0.00007
# [Epoch 24] Moving Train Loss 0.77164, Train Acc 0.90528, Valid Loss 0.76732, Valid Acc 0.78750, Time Consume 2.67600 s.lr: 0.00007
# [Epoch 25] Moving Train Loss 0.74443, Train Acc 0.90507, Valid Loss 0.77072, Valid Acc 0.79028, Time Consume 2.67500 s.lr: 0.00007
# [Epoch 26] Moving Train Loss 0.72997, Train Acc 0.90834, Valid Loss 0.76423, Valid Acc 0.78611, Time Consume 2.77400 s.lr: 0.00007
# [Epoch 27] Moving Train Loss 0.73644, Train Acc 0.91044, Valid Loss 0.75836, Valid Acc 0.79722, Time Consume 3.00900 s.lr: 0.00006
# [Epoch 28] Moving Train Loss 0.74110, Train Acc 0.91581, Valid Loss 0.75585, Valid Acc 0.79306, Time Consume 3.20800 s.lr: 0.00006
# [Epoch 29] Moving Train Loss 0.72611, Train Acc 0.91612, Valid Loss 0.76234, Valid Acc 0.79722, Time Consume 3.43700 s.lr: 0.00006
# [Epoch 30] Moving Train Loss 0.73386, Train Acc 0.91949, Valid Loss 0.75695, Valid Acc 0.79861, Time Consume 3.26700 s.lr: 0.00006
# [Epoch 31] Moving Train Loss 0.66951, Train Acc 0.92044, Valid Loss 0.74500, Valid Acc 0.79722, Time Consume 2.78500 s.lr: 0.00006
# [Epoch 32] Moving Train Loss 0.66914, Train Acc 0.92244, Valid Loss 0.74368, Valid Acc 0.80417, Time Consume 3.05100 s.lr: 0.00006
# [Epoch 33] Moving Train Loss 0.65752, Train Acc 0.92538, Valid Loss 0.74738, Valid Acc 0.80139, Time Consume 2.69100 s.lr: 0.00005
# [Epoch 34] Moving Train Loss 0.61523, Train Acc 0.92644, Valid Loss 0.74535, Valid Acc 0.79167, Time Consume 2.67400 s.lr: 0.00005
# [Epoch 35] Moving Train Loss 0.64597, Train Acc 0.93065, Valid Loss 0.73500, Valid Acc 0.79167, Time Consume 2.98500 s.lr: 0.00005
# [Epoch 36] Moving Train Loss 0.59442, Train Acc 0.93212, Valid Loss 0.73541, Valid Acc 0.79722, Time Consume 2.67400 s.lr: 0.00005
# [Epoch 37] Moving Train Loss 0.62956, Train Acc 0.93549, Valid Loss 0.73133, Valid Acc 0.79028, Time Consume 2.78300 s.lr: 0.00005
# [Epoch 38] Moving Train Loss 0.60311, Train Acc 0.93696, Valid Loss 0.72478, Valid Acc 0.79583, Time Consume 2.99700 s.lr: 0.00005
# [Epoch 39] Moving Train Loss 0.58741, Train Acc 0.93622, Valid Loss 0.73140, Valid Acc 0.80000, Time Consume 2.77200 s.lr: 0.00005
# [Epoch 40] Moving Train Loss 0.56469, Train Acc 0.93917, Valid Loss 0.73169, Valid Acc 0.79444, Time Consume 2.69800 s.lr: 0.00005
# [Epoch 41] Moving Train Loss 0.53718, Train Acc 0.93917, Valid Loss 0.72486, Valid Acc 0.80417, Time Consume 2.67200 s.lr: 0.00005
# [Epoch 42] Moving Train Loss 0.55420, Train Acc 0.94085, Valid Loss 0.72651, Valid Acc 0.79444, Time Consume 2.99100 s.lr: 0.00005
# [Epoch 43] Moving Train Loss 0.53936, Train Acc 0.94275, Valid Loss 0.72330, Valid Acc 0.80833, Time Consume 3.12400 s.lr: 0.00004
# [Epoch 44] Moving Train Loss 0.53033, Train Acc 0.94475, Valid Loss 0.72315, Valid Acc 0.79861, Time Consume 4.08400 s.lr: 0.00004
# [Epoch 45] Moving Train Loss 0.52039, Train Acc 0.94517, Valid Loss 0.71799, Valid Acc 0.79583, Time Consume 3.95300 s.lr: 0.00004
# [Epoch 46] Moving Train Loss 0.54683, Train Acc 0.94580, Valid Loss 0.71930, Valid Acc 0.80278, Time Consume 3.63200 s.lr: 0.00004
# [Epoch 47] Moving Train Loss 0.50055, Train Acc 0.94969, Valid Loss 0.71558, Valid Acc 0.80000, Time Consume 3.99300 s.lr: 0.00004
# [Epoch 48] Moving Train Loss 0.54041, Train Acc 0.94980, Valid Loss 0.71885, Valid Acc 0.80139, Time Consume 4.00800 s.lr: 0.00004
# [Epoch 49] Moving Train Loss 0.50979, Train Acc 0.94906, Valid Loss 0.71407, Valid Acc 0.80417, Time Consume 4.25100 s.lr: 0.00004
# [Epoch 50] Moving Train Loss 0.52002, Train Acc 0.95012, Valid Loss 0.71475, Valid Acc 0.80139, Time Consume 3.82400 s.lr: 0.00004
# [Epoch 51] Moving Train Loss 0.48840, Train Acc 0.95148, Valid Loss 0.71793, Valid Acc 0.80278, Time Consume 3.19400 s.lr: 0.00004
# [Epoch 52] Moving Train Loss 0.47606, Train Acc 0.95254, Valid Loss 0.71488, Valid Acc 0.80417, Time Consume 3.14000 s.lr: 0.00004
# [Epoch 53] Moving Train Loss 0.48713, Train Acc 0.95496, Valid Loss 0.71298, Valid Acc 0.80139, Time Consume 3.32700 s.lr: 0.00004
# [Epoch 54] Moving Train Loss 0.44385, Train Acc 0.95475, Valid Loss 0.72138, Valid Acc 0.79861, Time Consume 2.96200 s.lr: 0.00003
# [Epoch 55] Moving Train Loss 0.49391, Train Acc 0.95675, Valid Loss 0.71123, Valid Acc 0.80139, Time Consume 3.21200 s.lr: 0.00003
# [Epoch 56] Moving Train Loss 0.48473, Train Acc 0.95632, Valid Loss 0.70984, Valid Acc 0.80694, Time Consume 2.88800 s.lr: 0.00003
# [Epoch 57] Moving Train Loss 0.48290, Train Acc 0.95685, Valid Loss 0.71371, Valid Acc 0.80278, Time Consume 3.36500 s.lr: 0.00003
# [Epoch 58] Moving Train Loss 0.46307, Train Acc 0.95790, Valid Loss 0.70468, Valid Acc 0.80139, Time Consume 3.02300 s.lr: 0.00003
# [Epoch 59] Moving Train Loss 0.45898, Train Acc 0.95906, Valid Loss 0.70688, Valid Acc 0.80556, Time Consume 2.65400 s.lr: 0.00003
# [Epoch 60] Moving Train Loss 0.45482, Train Acc 0.96022, Valid Loss 0.71127, Valid Acc 0.80139, Time Consume 2.64800 s.lr: 0.00003
# [Epoch 61] Moving Train Loss 0.49575, Train Acc 0.95959, Valid Loss 0.70662, Valid Acc 0.80278, Time Consume 2.66700 s.lr: 0.00003
# [Epoch 62] Moving Train Loss 0.44824, Train Acc 0.95959, Valid Loss 0.70630, Valid Acc 0.80000, Time Consume 2.67200 s.lr: 0.00003
# [Epoch 63] Moving Train Loss 0.45994, Train Acc 0.95917, Valid Loss 0.71172, Valid Acc 0.80139, Time Consume 2.64800 s.lr: 0.00003
# [Epoch 64] Moving Train Loss 0.40185, Train Acc 0.96159, Valid Loss 0.70897, Valid Acc 0.80417, Time Consume 2.64700 s.lr: 0.00003
# [Epoch 65] Moving Train Loss 0.42960, Train Acc 0.96169, Valid Loss 0.71143, Valid Acc 0.80556, Time Consume 2.65000 s.lr: 0.00003
# [Epoch 66] Moving Train Loss 0.46142, Train Acc 0.96201, Valid Loss 0.70862, Valid Acc 0.80278, Time Consume 2.66000 s.lr: 0.00003
# [Epoch 67] Moving Train Loss 0.42981, Train Acc 0.96201, Valid Loss 0.70919, Valid Acc 0.80139, Time Consume 2.65000 s.lr: 0.00003
# [Epoch 68] Moving Train Loss 0.42526, Train Acc 0.96338, Valid Loss 0.70959, Valid Acc 0.80417, Time Consume 2.66300 s.lr: 0.00003
# [Epoch 69] Moving Train Loss 0.44315, Train Acc 0.96548, Valid Loss 0.71137, Valid Acc 0.80833, Time Consume 2.65500 s.lr: 0.00003
# [Epoch 70] Moving Train Loss 0.38664, Train Acc 0.96495, Valid Loss 0.71035, Valid Acc 0.80000, Time Consume 2.62600 s.lr: 0.00003
# [Epoch 71] Moving Train Loss 0.43320, Train Acc 0.96495, Valid Loss 0.70511, Valid Acc 0.80139, Time Consume 2.63900 s.lr: 0.00003
# [Epoch 72] Moving Train Loss 0.42983, Train Acc 0.96527, Valid Loss 0.70859, Valid Acc 0.80278, Time Consume 2.64800 s.lr: 0.00003
# [Epoch 73] Moving Train Loss 0.44103, Train Acc 0.96653, Valid Loss 0.70527, Valid Acc 0.80278, Time Consume 2.64400 s.lr: 0.00003
# [Epoch 74] Moving Train Loss 0.40053, Train Acc 0.96643, Valid Loss 0.70456, Valid Acc 0.79861, Time Consume 2.66700 s.lr: 0.00003
# [Epoch 75] Moving Train Loss 0.40295, Train Acc 0.96685, Valid Loss 0.70610, Valid Acc 0.80694, Time Consume 2.64000 s.lr: 0.00002
# [Epoch 76] Moving Train Loss 0.38329, Train Acc 0.96695, Valid Loss 0.70424, Valid Acc 0.80556, Time Consume 2.76500 s.lr: 0.00002
# [Epoch 77] Moving Train Loss 0.39689, Train Acc 0.96759, Valid Loss 0.70348, Valid Acc 0.80694, Time Consume 2.64200 s.lr: 0.00002
# [Epoch 78] Moving Train Loss 0.39123, Train Acc 0.96864, Valid Loss 0.70623, Valid Acc 0.80139, Time Consume 2.65700 s.lr: 0.00002
# [Epoch 79] Moving Train Loss 0.38676, Train Acc 0.96853, Valid Loss 0.70211, Valid Acc 0.80278, Time Consume 2.95600 s.lr: 0.00002
# [Epoch 80] Moving Train Loss 0.39208, Train Acc 0.96959, Valid Loss 0.70533, Valid Acc 0.80556, Time Consume 3.33100 s.lr: 0.00002
# [Epoch 81] Moving Train Loss 0.40773, Train Acc 0.96969, Valid Loss 0.70275, Valid Acc 0.80417, Time Consume 3.05800 s.lr: 0.00002
# [Epoch 82] Moving Train Loss 0.38100, Train Acc 0.97169, Valid Loss 0.70246, Valid Acc 0.80556, Time Consume 3.84000 s.lr: 0.00002
# [Epoch 83] Moving Train Loss 0.36625, Train Acc 0.97011, Valid Loss 0.70114, Valid Acc 0.80000, Time Consume 3.50500 s.lr: 0.00002
# [Epoch 84] Moving Train Loss 0.34975, Train Acc 0.97043, Valid Loss 0.70036, Valid Acc 0.80833, Time Consume 2.74400 s.lr: 0.00002
# [Epoch 85] Moving Train Loss 0.39308, Train Acc 0.97022, Valid Loss 0.69929, Valid Acc 0.80417, Time Consume 2.66100 s.lr: 0.00002
# [Epoch 86] Moving Train Loss 0.37398, Train Acc 0.97137, Valid Loss 0.69753, Valid Acc 0.80000, Time Consume 2.67000 s.lr: 0.00002
# [Epoch 87] Moving Train Loss 0.35357, Train Acc 0.97158, Valid Loss 0.70593, Valid Acc 0.80556, Time Consume 2.94500 s.lr: 0.00002
# [Epoch 88] Moving Train Loss 0.38266, Train Acc 0.97274, Valid Loss 0.70146, Valid Acc 0.80000, Time Consume 2.79600 s.lr: 0.00002
# [Epoch 89] Moving Train Loss 0.34286, Train Acc 0.97274, Valid Loss 0.70188, Valid Acc 0.80278, Time Consume 2.66100 s.lr: 0.00002
# [Epoch 90] Moving Train Loss 0.35989, Train Acc 0.97306, Valid Loss 0.70019, Valid Acc 0.79444, Time Consume 2.66500 s.lr: 0.00002
# [Epoch 91] Moving Train Loss 0.36316, Train Acc 0.97285, Valid Loss 0.69978, Valid Acc 0.80556, Time Consume 2.65500 s.lr: 0.00002
# [Epoch 92] Moving Train Loss 0.34727, Train Acc 0.97295, Valid Loss 0.70554, Valid Acc 0.80139, Time Consume 2.65600 s.lr: 0.00002
# [Epoch 93] Moving Train Loss 0.37885, Train Acc 0.97401, Valid Loss 0.70005, Valid Acc 0.80556, Time Consume 2.66500 s.lr: 0.00002
# [Epoch 94] Moving Train Loss 0.33866, Train Acc 0.97379, Valid Loss 0.70101, Valid Acc 0.80417, Time Consume 2.66000 s.lr: 0.00002
# [Epoch 95] Moving Train Loss 0.35360, Train Acc 0.97453, Valid Loss 0.70195, Valid Acc 0.80417, Time Consume 2.65800 s.lr: 0.00002
# [Epoch 96] Moving Train Loss 0.37531, Train Acc 0.97474, Valid Loss 0.70304, Valid Acc 0.80972, Time Consume 2.67200 s.lr: 0.00002
# [Epoch 97] Moving Train Loss 0.33445, Train Acc 0.97506, Valid Loss 0.70070, Valid Acc 0.80417, Time Consume 2.68300 s.lr: 0.00002
# [Epoch 98] Moving Train Loss 0.34140, Train Acc 0.97464, Valid Loss 0.70120, Valid Acc 0.80417, Time Consume 2.65600 s.lr: 0.00002
# [Epoch 99] Moving Train Loss 0.34126, Train Acc 0.97495, Valid Loss 0.70225, Valid Acc 0.80278, Time Consume 2.68000 s.lr: 0.00002
# [Epoch 100] Moving Train Loss 0.37608, Train Acc 0.97516, Valid Loss 0.69995, Valid Acc 0.80833, Time Consume 2.75900 s.lr: 0.00002
# 0.6999465723832449

# %% [markdown]
# ## 对测试集进行分类
#
# ### 载入测试集特征

# %%
feature_test = [nd.load(os.path.join(data_dir, model_features_dir, 'features_test_{}.nd'.format(model_name)))[0] 
                for model_name in model_names]
feature_test = nd.concat(*feature_test, dim=1)

# %% [markdown]
# ### 利用融合的模型进行预测

# %%
output = nd.softmax(classifier_net(feature_test.as_in_context(mx.gpu()))).asnumpy()

# %% [markdown]
# ### 将结果输出到csv文件进行提交

# %%
df_pred = pd.read_csv('sample_submission.csv')

# %%
for i, col_name in enumerate(df_pred.columns[1:]):
    df_pred[col_name] = output[:,i]
    
df_pred.to_csv('pred.csv', index=None)
