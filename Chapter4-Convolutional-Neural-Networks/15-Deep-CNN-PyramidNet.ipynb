# %% [markdown]
# # Deep Pyramidal Residual Networks
#
# 论文地址: [Deep Pyramidal Residual Networks](https://arxiv.org/abs/1610.02915)
#
# # ShakeDrop Regularization
#
# 论文地址: [ShakeDrop Regularization](https://arxiv.org/abs/1802.02375)

# %% [markdown]
# #### <font color="red">二者的结合可以在CIFAR-10/CIFAR-100上取得state-of-the-art的成绩
#
# ## PyramidNet
#
# 该网络主要在pre-activation版本的ResNet上提出了新的思想，主要包括两个方面
# * 新的Network Architecture
#   + 放弃传统地仅在下采样层阶段增加output channel而每个residual unit的num_filter都相同的做法，转而使得每个residual unit的outputchannel都逐级增加以分担仅在下采样层增加output channel的压力；
#   + 两种网络结构：
#
# <img src="../img/Chapter4-Convolutional-Neural-Networks/4-31.png" width="600">
#
# * 新的Building Block
#   + 丢弃每个residual unit中的第一个relu激活层
#   + 在每个residual unit最后加上额外的BN以加快收敛
#
# <img src="../img/Chapter4-Convolutional-Neural-Networks/4-32.png" width="800">
#
# ## ShakeDrop Regularization

# %%
import math

import mxnet as mx
import numpy as np

from mxnet import nd
from mxnet import image
from mxnet import gluon
from mxnet import autograd
mx.random.seed(1)

# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 120
import matplotlib.pyplot as plt

# %%
def BN_ReLU_Conv(num_filter, kernel_size, strides=1, padding=0, erase_relu=False):
    net = gluon.nn.HybridSequential()
    with net.name_scope():
        net.add(gluon.nn.BatchNorm(axis=1))
        if not erase_relu:
            net.add(gluon.nn.Activation('relu'))
        net.add(gluon.nn.Conv2D(num_filter, kernel_size=kernel_size, strides=strides, 
                                padding=padding, use_bias=False))
    return net

def BN_ReLU(erase_relu=False):
    '''
    erase_relu : Boolean
        whether erase relu
    '''
    net = gluon.nn.HybridSequential()
    with net.name_scope():
        net.add(gluon.nn.BatchNorm(axis=1))
        if not erase_relu:
            net.add(gluon.nn.Activation('relu'))
    return net

'''
BasicBlock
'''
class BasicBlock(gluon.nn.HybridBlock):
    outchannel_ratio = 1
    def __init__(self, out_channels, strides=1, downsample=None, **kwargs):
        super().__init__(**kwargs)
        blk = self.blk = gluon.nn.HybridSequential()
        self.downsample = downsample
        self.strides = strides
        with self.name_scope():
            blk.add(BN_ReLU_Conv(out_channels, kernel_size=3, strides=strides, padding=1, erase_relu=True))
            blk.add(BN_ReLU_Conv(out_channels * BasicBlock.outchannel_ratio, kernel_size=3, strides=1, padding=1))
            blk.add(gluon.nn.BatchNorm(axis=1))
        
    def hybrid_forward(self, F, X):
        out = self.blk(X)
        if self.downsample is not None:
            shortcut = self.downsample(X)
        else:
            shortcut = X
            
        residual_channel = out.shape[1]
        shortcut_channel = shortcut.shape[1]
        
        if residual_channel != shortcut_channel:
            # zero-padded shortcut connection
            shortcut = F.array(np.pad(shortcut.asnumpy(), pad_width=((0,0),(0,residual_channel - shortcut_channel),(0,0),(0,0)),
                            mode='constant', constant_values=0))      
        print((out + shortcut).shape)
        return out + shortcut
    
'''
Bottleneck
'''
class Bottleneck(gluon.nn.HybridBlock):
    outchannel_ratio = 4
    def __init__(self, out_channels, strides=1, downsample=None, **kwargs):
        super().__init__(**kwargs)
        blk = self.blk = gluon.nn.HybridSequential()
        self.downsample = downsample
        self.strides = strides
        with self.name_scope():
            blk.add(BN_ReLU_Conv(out_channels, kernel_size=1, erase_relu=True))
            blk.add(BN_ReLU_Conv(out_channels, kernel_size=3, strides=strides, padding=1))
            blk.add(BN_ReLU_Conv(out_channels * Bottleneck.outchannel_ratio, kernel_size=1))
            blk.add(gluon.nn.BatchNorm(axis=1))
        
    def hybrid_forward(self, F, X):
        out = self.blk(X)
        if self.downsample is not None:
            shortcut = self.downsample(X)
        else:
            shortcut = X
            
        residual_channel = out.shape[1]
        shortcut_channel = shortcut.shape[1]
        
        if residual_channel != shortcut_channel:
            # zero-padded shortcut connection
            shortcut = F.array(np.pad(shortcut.asnumpy(), pad_width=((0,0),(0,residual_channel - shortcut_channel),(0,0),(0,0)),
                            mode='constant', constant_values=0))      
        print((out + shortcut).shape)
        return out + shortcut

def pyramidal_residual_layer(block, block_depth, fm_dim, add_rate, strides=1):
    downsample = None
    if strides != 1:
        downsample = gluon.nn.AvgPool2D(pool_size=2, strides=2)
    residual = gluon.nn.HybridSequential()
    with residual.name_scope():
        fm_dim = fm_dim + add_rate
        # first downsample layer
        residual.add(block(int(round(fm_dim)), strides, downsample))
        for i in range(1, int(block_depth)):
            tmp_fm_dim = fm_dim + add_rate
            residual.add(block(int(round(tmp_fm_dim)), 1))
            fm_dim = tmp_fm_dim

    '''
    the reason for multiply the outchannel_ratio is that, whether in BasicBlock or Bottleneck, we 
    multiply the outchannel_ratio to the last conv block to enlarge its channel.And we count the 
    channel to feed into the last classification layer.
    '''
    # fm_dim *= block.outchannel_ratio
    return residual, fm_dim

class PyramidNet(gluon.nn.HybridBlock):
    def __init__(self, depth, alpha, inchannels, num_classes, bottleneck=False, debug=False, **kwargs):
        super().__init__(**kwargs)
        self.debug = debug
        
        if bottleneck:
            n = (depth - 2) / 9
            block = Bottleneck
        else:
            n = (depth - 2) / 6
            block = BasicBlock
            
        addrate = alpha / (3 * n * 1.0)
        featuremap_dim = inchannels # init fm_dim
            
        net = self.net = gluon.nn.HybridSequential()
        with self.name_scope():
            blk1 = gluon.nn.HybridSequential()
            blk1.add(
                gluon.nn.Conv2D(featuremap_dim, kernel_size=3, strides=1, padding=1, use_bias=False),
                gluon.nn.BatchNorm(axis=1)
            )
            
            blk2, featuremap_dim = pyramidal_residual_layer(block, n, featuremap_dim, addrate)
            blk3, featuremap_dim = pyramidal_residual_layer(block, n, featuremap_dim, addrate, strides=2)
            blk4, _ = pyramidal_residual_layer(block, n, featuremap_dim, addrate, strides=2)

            blk5 = gluon.nn.HybridSequential()
            blk5.add(
                gluon.nn.BatchNorm(axis=1),
                gluon.nn.Activation('relu'),
                gluon.nn.GlobalAvgPool2D(),
                gluon.nn.Dense(num_classes)
            )
        
        net.add(blk1, blk2, blk3, blk4, blk5)
        
    def hybrid_forward(self, F, X):
        out = X
        for i, blk in enumerate(self.net):
            out = blk(out)
            if self.debug:
                print("blk {} : {}".format(i+1, out.shape))
        return out

# %%
pyramidnet = PyramidNet(depth=200, alpha=240, inchannels=16, num_classes=10, bottleneck=True, debug=True)
pyramidnet.initialize()
X = nd.random.normal(shape=(1,3,32,32))
y = pyramidnet(X)
# Out:
# blk 1 : (1, 16, 32, 32)
# (1, 80, 32, 32)
# (1, 92, 32, 32)
# (1, 108, 32, 32)
# (1, 124, 32, 32)
# (1, 136, 32, 32)
# (1, 152, 32, 32)
# (1, 164, 32, 32)
# (1, 180, 32, 32)
# (1, 196, 32, 32)
# (1, 208, 32, 32)
# (1, 224, 32, 32)
# (1, 240, 32, 32)
# (1, 252, 32, 32)
# (1, 268, 32, 32)
# (1, 284, 32, 32)
# (1, 296, 32, 32)
# (1, 312, 32, 32)
# (1, 324, 32, 32)
# (1, 340, 32, 32)
# (1, 356, 32, 32)
# (1, 368, 32, 32)
# (1, 384, 32, 32)
# blk 2 : (1, 384, 32, 32)
# (1, 400, 16, 16)
# (1, 412, 16, 16)
# (1, 428, 16, 16)
# (1, 444, 16, 16)
# (1, 456, 16, 16)
# (1, 472, 16, 16)
# (1, 484, 16, 16)
# (1, 500, 16, 16)
# (1, 516, 16, 16)
# (1, 528, 16, 16)
# (1, 544, 16, 16)
# (1, 560, 16, 16)
# (1, 572, 16, 16)
# (1, 588, 16, 16)
# (1, 604, 16, 16)
# (1, 616, 16, 16)
# (1, 632, 16, 16)
# (1, 644, 16, 16)
# (1, 660, 16, 16)
# (1, 676, 16, 16)
# (1, 688, 16, 16)
# (1, 704, 16, 16)
# blk 3 : (1, 704, 16, 16)
# (1, 720, 8, 8)
# (1, 732, 8, 8)
# (1, 748, 8, 8)
# (1, 764, 8, 8)
# (1, 776, 8, 8)
# (1, 792, 8, 8)
# (1, 804, 8, 8)
# (1, 820, 8, 8)
# (1, 836, 8, 8)
# (1, 848, 8, 8)
# (1, 864, 8, 8)
# (1, 880, 8, 8)
# (1, 892, 8, 8)
# (1, 908, 8, 8)
# (1, 924, 8, 8)
# (1, 936, 8, 8)
# (1, 952, 8, 8)
# (1, 964, 8, 8)
# (1, 980, 8, 8)
# (1, 996, 8, 8)
# (1, 1008, 8, 8)
# (1, 1024, 8, 8)
# blk 4 : (1, 1024, 8, 8)
# blk 5 : (1, 10)

# %%
pyramidnet
# Out:
# PyramidNet(
#   (net): HybridSequential(
#     (0): HybridSequential(
#       (0): Conv2D(2 -> 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (1): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=16)
#     )
#     (1): HybridSequential(
#       (0): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=16)
#             (1): Conv2D(16 -> 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=20)
#             (1): Activation(relu)
#             (2): Conv2D(20 -> 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=20)
#             (1): Activation(relu)
#             (2): Conv2D(20 -> 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=80)
#         )
#       )
#       (1): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=80)
#             (1): Conv2D(80 -> 23, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=23)
#             (1): Activation(relu)
#             (2): Conv2D(23 -> 23, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=23)
#             (1): Activation(relu)
#             (2): Conv2D(23 -> 92, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=92)
#         )
#       )
#       (2): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=92)
#             (1): Conv2D(92 -> 27, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=27)
#             (1): Activation(relu)
#             (2): Conv2D(27 -> 27, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=27)
#             (1): Activation(relu)
#             (2): Conv2D(27 -> 108, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=108)
#         )
#       )
#       (3): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=108)
#             (1): Conv2D(108 -> 31, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=31)
#             (1): Activation(relu)
#             (2): Conv2D(31 -> 31, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=31)
#             (1): Activation(relu)
#             (2): Conv2D(31 -> 124, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=124)
#         )
#       )
#       (4): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=124)
#             (1): Conv2D(124 -> 34, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=34)
#             (1): Activation(relu)
#             (2): Conv2D(34 -> 34, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=34)
#             (1): Activation(relu)
#             (2): Conv2D(34 -> 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=136)
#         )
#       )
#       (5): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=136)
#             (1): Conv2D(136 -> 38, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=38)
#             (1): Activation(relu)
#             (2): Conv2D(38 -> 38, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=38)
#             (1): Activation(relu)
#             (2): Conv2D(38 -> 152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=152)
#         )
#       )
#       (6): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=152)
#             (1): Conv2D(152 -> 41, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=41)
#             (1): Activation(relu)
#             (2): Conv2D(41 -> 41, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=41)
#             (1): Activation(relu)
#             (2): Conv2D(41 -> 164, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=164)
#         )
#       )
#       (7): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=164)
#             (1): Conv2D(164 -> 45, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=45)
#             (1): Activation(relu)
#             (2): Conv2D(45 -> 45, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=45)
#             (1): Activation(relu)
#             (2): Conv2D(45 -> 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=180)
#         )
#       )
#       (8): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=180)
#             (1): Conv2D(180 -> 49, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=49)
#             (1): Activation(relu)
#             (2): Conv2D(49 -> 49, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=49)
#             (1): Activation(relu)
#             (2): Conv2D(49 -> 196, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=196)
#         )
#       )
#       (9): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=196)
#             (1): Conv2D(196 -> 52, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=52)
#             (1): Activation(relu)
#             (2): Conv2D(52 -> 52, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=52)
#             (1): Activation(relu)
#             (2): Conv2D(52 -> 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=208)
#         )
#       )
#       (10): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=208)
#             (1): Conv2D(208 -> 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=56)
#             (1): Activation(relu)
#             (2): Conv2D(56 -> 56, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=56)
#             (1): Activation(relu)
#             (2): Conv2D(56 -> 224, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=224)
#         )
#       )
#       (11): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=224)
#             (1): Conv2D(224 -> 60, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=60)
#             (1): Activation(relu)
#             (2): Conv2D(60 -> 60, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=60)
#             (1): Activation(relu)
#             (2): Conv2D(60 -> 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=240)
#         )
#       )
#       (12): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=240)
#             (1): Conv2D(240 -> 63, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=63)
#             (1): Activation(relu)
#             (2): Conv2D(63 -> 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=63)
#             (1): Activation(relu)
#             (2): Conv2D(63 -> 252, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=252)
#         )
#       )
#       (13): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=252)
#             (1): Conv2D(252 -> 67, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=67)
#             (1): Activation(relu)
#             (2): Conv2D(67 -> 67, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=67)
#             (1): Activation(relu)
#             (2): Conv2D(67 -> 268, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=268)
#         )
#       )
#       (14): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=268)
#             (1): Conv2D(268 -> 71, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=71)
#             (1): Activation(relu)
#             (2): Conv2D(71 -> 71, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=71)
#             (1): Activation(relu)
#             (2): Conv2D(71 -> 284, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=284)
#         )
#       )
#       (15): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=284)
#             (1): Conv2D(284 -> 74, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=74)
#             (1): Activation(relu)
#             (2): Conv2D(74 -> 74, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=74)
#             (1): Activation(relu)
#             (2): Conv2D(74 -> 296, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=296)
#         )
#       )
#       (16): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=296)
#             (1): Conv2D(296 -> 78, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=78)
#             (1): Activation(relu)
#             (2): Conv2D(78 -> 78, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=78)
#             (1): Activation(relu)
#             (2): Conv2D(78 -> 312, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=312)
#         )
#       )
#       (17): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=312)
#             (1): Conv2D(312 -> 81, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=81)
#             (1): Activation(relu)
#             (2): Conv2D(81 -> 81, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=81)
#             (1): Activation(relu)
#             (2): Conv2D(81 -> 324, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=324)
#         )
#       )
#       (18): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=324)
#             (1): Conv2D(324 -> 85, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=85)
#             (1): Activation(relu)
#             (2): Conv2D(85 -> 85, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=85)
#             (1): Activation(relu)
#             (2): Conv2D(85 -> 340, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=340)
#         )
#       )
#       (19): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=340)
#             (1): Conv2D(340 -> 89, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=89)
#             (1): Activation(relu)
#             (2): Conv2D(89 -> 89, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=89)
#             (1): Activation(relu)
#             (2): Conv2D(89 -> 356, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=356)
#         )
#       )
#       (20): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=356)
#             (1): Conv2D(356 -> 92, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=92)
#             (1): Activation(relu)
#             (2): Conv2D(92 -> 92, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=92)
#             (1): Activation(relu)
#             (2): Conv2D(92 -> 368, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=368)
#         )
#       )
#       (21): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=368)
#             (1): Conv2D(368 -> 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=96)
#             (1): Activation(relu)
#             (2): Conv2D(96 -> 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=96)
#             (1): Activation(relu)
#             (2): Conv2D(96 -> 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=384)
#         )
#       )
#     )
#     (2): HybridSequential(
#       (0): Bottleneck(
#         (downsample): AvgPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=384)
#             (1): Conv2D(384 -> 100, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=100)
#             (1): Activation(relu)
#             (2): Conv2D(100 -> 100, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=100)
#             (1): Activation(relu)
#             (2): Conv2D(100 -> 400, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=400)
#         )
#       )
#       (1): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=400)
#             (1): Conv2D(400 -> 103, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=103)
#             (1): Activation(relu)
#             (2): Conv2D(103 -> 103, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=103)
#             (1): Activation(relu)
#             (2): Conv2D(103 -> 412, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=412)
#         )
#       )
#       (2): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=412)
#             (1): Conv2D(412 -> 107, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=107)
#             (1): Activation(relu)
#             (2): Conv2D(107 -> 107, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=107)
#             (1): Activation(relu)
#             (2): Conv2D(107 -> 428, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=428)
#         )
#       )
#       (3): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=428)
#             (1): Conv2D(428 -> 111, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=111)
#             (1): Activation(relu)
#             (2): Conv2D(111 -> 111, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=111)
#             (1): Activation(relu)
#             (2): Conv2D(111 -> 444, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=444)
#         )
#       )
#       (4): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=444)
#             (1): Conv2D(444 -> 114, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=114)
#             (1): Activation(relu)
#             (2): Conv2D(114 -> 114, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=114)
#             (1): Activation(relu)
#             (2): Conv2D(114 -> 456, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=456)
#         )
#       )
#       (5): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=456)
#             (1): Conv2D(456 -> 118, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=118)
#             (1): Activation(relu)
#             (2): Conv2D(118 -> 118, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=118)
#             (1): Activation(relu)
#             (2): Conv2D(118 -> 472, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=472)
#         )
#       )
#       (6): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=472)
#             (1): Conv2D(472 -> 121, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=121)
#             (1): Activation(relu)
#             (2): Conv2D(121 -> 121, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=121)
#             (1): Activation(relu)
#             (2): Conv2D(121 -> 484, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=484)
#         )
#       )
#       (7): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=484)
#             (1): Conv2D(484 -> 125, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=125)
#             (1): Activation(relu)
#             (2): Conv2D(125 -> 125, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=125)
#             (1): Activation(relu)
#             (2): Conv2D(125 -> 500, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=500)
#         )
#       )
#       (8): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=500)
#             (1): Conv2D(500 -> 129, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=129)
#             (1): Activation(relu)
#             (2): Conv2D(129 -> 129, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=129)
#             (1): Activation(relu)
#             (2): Conv2D(129 -> 516, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=516)
#         )
#       )
#       (9): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=516)
#             (1): Conv2D(516 -> 132, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=132)
#             (1): Activation(relu)
#             (2): Conv2D(132 -> 132, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=132)
#             (1): Activation(relu)
#             (2): Conv2D(132 -> 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=528)
#         )
#       )
#       (10): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=528)
#             (1): Conv2D(528 -> 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=136)
#             (1): Activation(relu)
#             (2): Conv2D(136 -> 136, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=136)
#             (1): Activation(relu)
#             (2): Conv2D(136 -> 544, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=544)
#         )
#       )
#       (11): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=544)
#             (1): Conv2D(544 -> 140, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=140)
#             (1): Activation(relu)
#             (2): Conv2D(140 -> 140, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=140)
#             (1): Activation(relu)
#             (2): Conv2D(140 -> 560, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=560)
#         )
#       )
#       (12): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=560)
#             (1): Conv2D(560 -> 143, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=143)
#             (1): Activation(relu)
#             (2): Conv2D(143 -> 143, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=143)
#             (1): Activation(relu)
#             (2): Conv2D(143 -> 572, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=572)
#         )
#       )
#       (13): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=572)
#             (1): Conv2D(572 -> 147, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=147)
#             (1): Activation(relu)
#             (2): Conv2D(147 -> 147, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=147)
#             (1): Activation(relu)
#             (2): Conv2D(147 -> 588, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=588)
#         )
#       )
#       (14): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=588)
#             (1): Conv2D(588 -> 151, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=151)
#             (1): Activation(relu)
#             (2): Conv2D(151 -> 151, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=151)
#             (1): Activation(relu)
#             (2): Conv2D(151 -> 604, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=604)
#         )
#       )
#       (15): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=604)
#             (1): Conv2D(604 -> 154, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=154)
#             (1): Activation(relu)
#             (2): Conv2D(154 -> 154, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=154)
#             (1): Activation(relu)
#             (2): Conv2D(154 -> 616, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=616)
#         )
#       )
#       (16): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=616)
#             (1): Conv2D(616 -> 158, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=158)
#             (1): Activation(relu)
#             (2): Conv2D(158 -> 158, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=158)
#             (1): Activation(relu)
#             (2): Conv2D(158 -> 632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=632)
#         )
#       )
#       (17): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=632)
#             (1): Conv2D(632 -> 161, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=161)
#             (1): Activation(relu)
#             (2): Conv2D(161 -> 161, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=161)
#             (1): Activation(relu)
#             (2): Conv2D(161 -> 644, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=644)
#         )
#       )
#       (18): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=644)
#             (1): Conv2D(644 -> 165, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=165)
#             (1): Activation(relu)
#             (2): Conv2D(165 -> 165, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=165)
#             (1): Activation(relu)
#             (2): Conv2D(165 -> 660, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=660)
#         )
#       )
#       (19): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=660)
#             (1): Conv2D(660 -> 169, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=169)
#             (1): Activation(relu)
#             (2): Conv2D(169 -> 169, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=169)
#             (1): Activation(relu)
#             (2): Conv2D(169 -> 676, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=676)
#         )
#       )
#       (20): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=676)
#             (1): Conv2D(676 -> 172, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=172)
#             (1): Activation(relu)
#             (2): Conv2D(172 -> 172, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=172)
#             (1): Activation(relu)
#             (2): Conv2D(172 -> 688, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=688)
#         )
#       )
#       (21): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=688)
#             (1): Conv2D(688 -> 176, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=176)
#             (1): Activation(relu)
#             (2): Conv2D(176 -> 176, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=176)
#             (1): Activation(relu)
#             (2): Conv2D(176 -> 704, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=704)
#         )
#       )
#     )
#     (3): HybridSequential(
#       (0): Bottleneck(
#         (downsample): AvgPool2D(size=(2, 2), stride=(2, 2), padding=(0, 0), ceil_mode=False)
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=704)
#             (1): Conv2D(704 -> 180, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=180)
#             (1): Activation(relu)
#             (2): Conv2D(180 -> 180, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=180)
#             (1): Activation(relu)
#             (2): Conv2D(180 -> 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=720)
#         )
#       )
#       (1): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=720)
#             (1): Conv2D(720 -> 183, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=183)
#             (1): Activation(relu)
#             (2): Conv2D(183 -> 183, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=183)
#             (1): Activation(relu)
#             (2): Conv2D(183 -> 732, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=732)
#         )
#       )
#       (2): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=732)
#             (1): Conv2D(732 -> 187, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=187)
#             (1): Activation(relu)
#             (2): Conv2D(187 -> 187, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=187)
#             (1): Activation(relu)
#             (2): Conv2D(187 -> 748, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=748)
#         )
#       )
#       (3): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=748)
#             (1): Conv2D(748 -> 191, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=191)
#             (1): Activation(relu)
#             (2): Conv2D(191 -> 191, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=191)
#             (1): Activation(relu)
#             (2): Conv2D(191 -> 764, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=764)
#         )
#       )
#       (4): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=764)
#             (1): Conv2D(764 -> 194, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=194)
#             (1): Activation(relu)
#             (2): Conv2D(194 -> 194, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=194)
#             (1): Activation(relu)
#             (2): Conv2D(194 -> 776, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=776)
#         )
#       )
#       (5): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=776)
#             (1): Conv2D(776 -> 198, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=198)
#             (1): Activation(relu)
#             (2): Conv2D(198 -> 198, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=198)
#             (1): Activation(relu)
#             (2): Conv2D(198 -> 792, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=792)
#         )
#       )
#       (6): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=792)
#             (1): Conv2D(792 -> 201, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=201)
#             (1): Activation(relu)
#             (2): Conv2D(201 -> 201, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=201)
#             (1): Activation(relu)
#             (2): Conv2D(201 -> 804, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=804)
#         )
#       )
#       (7): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=804)
#             (1): Conv2D(804 -> 205, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=205)
#             (1): Activation(relu)
#             (2): Conv2D(205 -> 205, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=205)
#             (1): Activation(relu)
#             (2): Conv2D(205 -> 820, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=820)
#         )
#       )
#       (8): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=820)
#             (1): Conv2D(820 -> 209, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=209)
#             (1): Activation(relu)
#             (2): Conv2D(209 -> 209, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=209)
#             (1): Activation(relu)
#             (2): Conv2D(209 -> 836, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=836)
#         )
#       )
#       (9): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=836)
#             (1): Conv2D(836 -> 212, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=212)
#             (1): Activation(relu)
#             (2): Conv2D(212 -> 212, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=212)
#             (1): Activation(relu)
#             (2): Conv2D(212 -> 848, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=848)
#         )
#       )
#       (10): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=848)
#             (1): Conv2D(848 -> 216, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=216)
#             (1): Activation(relu)
#             (2): Conv2D(216 -> 216, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=216)
#             (1): Activation(relu)
#             (2): Conv2D(216 -> 864, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=864)
#         )
#       )
#       (11): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=864)
#             (1): Conv2D(864 -> 220, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=220)
#             (1): Activation(relu)
#             (2): Conv2D(220 -> 220, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=220)
#             (1): Activation(relu)
#             (2): Conv2D(220 -> 880, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=880)
#         )
#       )
#       (12): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=880)
#             (1): Conv2D(880 -> 223, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=223)
#             (1): Activation(relu)
#             (2): Conv2D(223 -> 223, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=223)
#             (1): Activation(relu)
#             (2): Conv2D(223 -> 892, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=892)
#         )
#       )
#       (13): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=892)
#             (1): Conv2D(892 -> 227, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=227)
#             (1): Activation(relu)
#             (2): Conv2D(227 -> 227, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=227)
#             (1): Activation(relu)
#             (2): Conv2D(227 -> 908, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=908)
#         )
#       )
#       (14): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=908)
#             (1): Conv2D(908 -> 231, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=231)
#             (1): Activation(relu)
#             (2): Conv2D(231 -> 231, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=231)
#             (1): Activation(relu)
#             (2): Conv2D(231 -> 924, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=924)
#         )
#       )
#       (15): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=924)
#             (1): Conv2D(924 -> 234, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=234)
#             (1): Activation(relu)
#             (2): Conv2D(234 -> 234, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=234)
#             (1): Activation(relu)
#             (2): Conv2D(234 -> 936, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=936)
#         )
#       )
#       (16): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=936)
#             (1): Conv2D(936 -> 238, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=238)
#             (1): Activation(relu)
#             (2): Conv2D(238 -> 238, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=238)
#             (1): Activation(relu)
#             (2): Conv2D(238 -> 952, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=952)
#         )
#       )
#       (17): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=952)
#             (1): Conv2D(952 -> 241, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=241)
#             (1): Activation(relu)
#             (2): Conv2D(241 -> 241, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=241)
#             (1): Activation(relu)
#             (2): Conv2D(241 -> 964, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=964)
#         )
#       )
#       (18): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=964)
#             (1): Conv2D(964 -> 245, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=245)
#             (1): Activation(relu)
#             (2): Conv2D(245 -> 245, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=245)
#             (1): Activation(relu)
#             (2): Conv2D(245 -> 980, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=980)
#         )
#       )
#       (19): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=980)
#             (1): Conv2D(980 -> 249, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=249)
#             (1): Activation(relu)
#             (2): Conv2D(249 -> 249, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=249)
#             (1): Activation(relu)
#             (2): Conv2D(249 -> 996, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=996)
#         )
#       )
#       (20): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=996)
#             (1): Conv2D(996 -> 252, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=252)
#             (1): Activation(relu)
#             (2): Conv2D(252 -> 252, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=252)
#             (1): Activation(relu)
#             (2): Conv2D(252 -> 1008, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=1008)
#         )
#       )
#       (21): Bottleneck(
#         (blk): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=1008)
#             (1): Conv2D(1008 -> 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=256)
#             (1): Activation(relu)
#             (2): Conv2D(256 -> 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           )
#           (2): HybridSequential(
#             (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=256)
#             (1): Activation(relu)
#             (2): Conv2D(256 -> 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=1024)
#         )
#       )
#     )
#     (4): HybridSequential(
#       (0): BatchNorm(momentum=0.9, fix_gamma=False, axis=1, eps=1e-05, in_channels=1024)
#       (1): Activation(relu)
#       (2): GlobalAvgPool2D(size=(1, 1), stride=(1, 1), padding=(0, 0), ceil_mode=True)
#       (3): Dense(1024 -> 10, linear)
#     )
#   )
# )
