# %%
import mxnet as mx
import numpy as np

from mxnet import nd
from mxnet import gluon
from mxnet.gluon import nn

mx.random.seed(1)
ctx = mx.gpu()

# %% [markdown]
# ## DenseNet-BC

# %%
def BN_ReLU_Conv(num_filters, kernel_size, strides=1, padding=0, erase_relu=False):
    '''
    num_filters : int
        the output channel of this module
    kernel_size : int or tuple
        conv kernel
    strides : int or tuple
        conv strides
    padding : int or tuple
        conv padding
    erase_relu : bool
        whethr erase the relu activation
    '''
    net = gluon.nn.HybridSequential()
    with net.name_scope():
        net.add(gluon.nn.BatchNorm(axis=1, epsilon=2e-5))
        if erase_relu:
            net.add(gluon.nn.Activation('relu'))
        net.add(gluon.nn.Conv2D(num_filters, kernel_size=kernel_size, strides=strides, 
                                padding=padding, use_bias=False))
    return net

'''
BasicBlock
'''
class BasicBlock(gluon.nn.HybridBlock):
    def __init__(self, growth_rate, strides, bottleneck=False, drop_rate=0.0, **kwargs):
        '''
        growth_rate : int
        strides : step
        bottleneck : bool
        drop_rate : float
        '''
        super().__init__(**kwargs)
        blk = self.blk = gluon.nn.HybridSequential()
        with self.name_scope():
            if bottleneck:
                blk.add(BN_ReLU_Conv(int(growth_rate * 4), kernel_size=1))
                if drop_rate > 0.0:
                    blk.add(gluon.nn.Dropout(drop_rate))
                blk.add(BN_ReLU_Conv(int(growth_rate), kernel_size=3, strides=strides, padding=1))
                if drop_rate > 0.0:
                    blk.add(gluon.nn.Dropout(drop_rate))
            else:
                blk.add(BN_ReLU_Conv(int(growth_rate), kernel_size=3, strides=1))
                if drop_rate > 0.0:
                    blk.add(gluon.nn.Dropout(drop_rate))
                    
    def hybrid_forward(self, F, X):
        out = self.blk(X)
        return out
    
'''
DenseBlock
'''
class DenseBlock(gluon.nn.HybridBlock):
    def __init__(self, num_units, growth_rate, strides=1, bottleneck=False, drop_rate=0.0, **kwargs):
        '''
        num_units : int 
            each denseblock have num_units basicblock
        growth_rate : int
            the output channel of the 
        '''
        super().__init__(**kwargs)
        net = self.net = gluon.nn.HybridSequential()
        with self.name_scope():
            for i in range(num_units):
                net.add(BasicBlock(growth_rate, strides=strides, bottleneck=bottleneck, drop_rate=drop_rate))
    
    def hybrid_forward(self, F, X):
        for i, blk in enumerate(self.net):
            out = blk(X)
            X = F.concat(X, out, dim=1)
        return X
    
'''
TransitionBlock
'''
class TransitionBlock(gluon.nn.HybridBlock):
    def __init__(self, num_filter, strides=1, drop_rate=0.0, **kwargs):
        super().__init__(**kwargs)
        trans = self.trans = gluon.nn.HybridSequential()
        with self.name_scope():
            trans.add(BN_ReLU_Conv(num_filter, kernel_size=1, strides=strides))
            if drop_rate > 0.0:
                trans.add(gluon.nn.Dropout(drop_rate))
            trans.add(gluon.nn.AvgPool2D(pool_size=2, strides=2))
    
    def hybrid_forward(self, F, X):
        out = self.trans(X)
        return out
    
class DenseNet(gluon.nn.HybridBlock):
    def __init__(self, depth, num_stages, growth_rate, num_classes, data_type, reduction=0.5, 
                 bottleneck=False, drop_rate=0.0, debug=False, **kwargs):
        super().__init__(**kwargs)
        self.debug = debug
        
        if (depth - 4) % 3:
            raise Exception("Invalid Error!")
        
        if data_type == 'cifar':
            units = [(depth - 4) // 6 if bottleneck else 3] * num_stages
        else:
            raise ValueError('Not Implementation {} yet.'.format(data_type))
            
        num_units = len(units)
        assert(num_units == num_stages)
        n_channels = init_channels = 16 if data_type=="cifar" else 2 * growth_rate
        densenet = self.densenet = gluon.nn.HybridSequential()
        with self.name_scope():
            blk1 = gluon.nn.HybridSequential()
            blk1.add(gluon.nn.BatchNorm(axis=1, epsilon=2e-5))
            if data_type == 'cifar':
                blk1.add(gluon.nn.Conv2D(init_channels, kernel_size=3, padding=1, use_bias=False))
            elif data_type == 'imagenet':
                blk1.add(gluon.nn.Conv2D(init_channels, kernel_size=7, strides=2, padding=3, use_bias=False))
                blk1.add(gluon.nn.BatchNorm(axi=1, epsilon=2e-5))
                blk1.add(gluon.nn.Activation('relu'))
                blk1.add(gluon.nn.MaxPool2D(pool_size=3, strides=2, padding=1))
            densenet.add(blk1)
    
            for i in range(num_stages-1):
                blk2 = gluon.nn.HybridSequential()
                blk2.add(DenseBlock(units[i], growth_rate, bottleneck=bottleneck, drop_rate=drop_rate))
                # count channels to prepare for the transition block
                n_channels += units[i] * growth_rate
                n_channels = int(np.floor(n_channels * reduction))
                blk2.add(TransitionBlock(n_channels, strides=1, drop_rate=drop_rate))
                densenet.add(blk2)
            densenet.add(DenseBlock(units[num_stages-1], growth_rate, bottleneck=bottleneck, drop_rate=drop_rate))
            
            blk3 = gluon.nn.HybridSequential()
            blk3.add(
                gluon.nn.BatchNorm(axis=1, epsilon=2e-5),
                gluon.nn.Activation('relu')
            )
            densenet.add(blk3)
            
            blk4 = gluon.nn.HybridSequential()
            blk4.add(
                gluon.nn.GlobalAvgPool2D(),
                gluon.nn.Dense(num_classes)
            )
            densenet.add(blk4)
            
    def hybrid_forward(self, F, X):
        out = X
        for i, blk in enumerate(self.densenet):
            out = blk(out)
            if self.debug:
                print("blk {} : {}".format(i+1, out.shape))
        return out

# %%
symbol = DenseNet(depth=100, num_stages=3, growth_rate=12, num_classes=10, data_type='cifar', 
                  bottleneck=True, drop_rate=0.2, debug=True)
symbol.collect_params().initialize()

# %%
sample = nd.random.normal(shape=(1,3,32,32))
y = symbol(sample)
# Out:
# blk 1 : (1, 16, 32, 32)
# blk 2 : (1, 104, 32, 32)
# blk 3 : (1, 148, 32, 32)
# blk 4 : (1, 340, 32, 32)
# blk 5 : (1, 340, 32, 32)
# blk 6 : (1, 10)

# %%
symbol
# Out:
# DenseNet(
#   (densenet): HybridSequential(
#     (0): HybridSequential(
#       (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=3)
#       (1): Conv2D(3 -> 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): HybridSequential(
#       (0): DenseBlock(
#         (net): HybridSequential(
#           (0): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=16)
#                 (1): Conv2D(16 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (1): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=28)
#                 (1): Conv2D(28 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (2): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=40)
#                 (1): Conv2D(40 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (3): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=52)
#                 (1): Conv2D(52 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (4): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=64)
#                 (1): Conv2D(64 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (5): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=76)
#                 (1): Conv2D(76 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (6): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=88)
#                 (1): Conv2D(88 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (7): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=100)
#                 (1): Conv2D(100 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (8): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=112)
#                 (1): Conv2D(112 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (9): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=124)
#                 (1): Conv2D(124 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (10): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=136)
#                 (1): Conv2D(136 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (11): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=148)
#                 (1): Conv2D(148 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (12): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=160)
#                 (1): Conv2D(160 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (13): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=172)
#                 (1): Conv2D(172 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (14): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=184)
#                 (1): Conv2D(184 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (15): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=196)
#                 (1): Conv2D(196 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#         )
#       )
#       (1): TransitionBlock(
#         (trans): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=208)
#             (1): Conv2D(208 -> 104, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): Dropout(p = 0.2)
#         )
#       )
#     )
#     (2): HybridSequential(
#       (0): DenseBlock(
#         (net): HybridSequential(
#           (0): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=104)
#                 (1): Conv2D(104 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (1): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=116)
#                 (1): Conv2D(116 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (2): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=128)
#                 (1): Conv2D(128 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (3): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=140)
#                 (1): Conv2D(140 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (4): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=152)
#                 (1): Conv2D(152 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (5): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=164)
#                 (1): Conv2D(164 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (6): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=176)
#                 (1): Conv2D(176 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (7): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=188)
#                 (1): Conv2D(188 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (8): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=200)
#                 (1): Conv2D(200 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (9): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=212)
#                 (1): Conv2D(212 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (10): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=224)
#                 (1): Conv2D(224 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (11): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=236)
#                 (1): Conv2D(236 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (12): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=248)
#                 (1): Conv2D(248 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (13): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=260)
#                 (1): Conv2D(260 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (14): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=272)
#                 (1): Conv2D(272 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#           (15): BasicBlock(
#             (blk): HybridSequential(
#               (0): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=284)
#                 (1): Conv2D(284 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               )
#               (1): Dropout(p = 0.2)
#               (2): HybridSequential(
#                 (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#                 (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               )
#               (3): Dropout(p = 0.2)
#             )
#           )
#         )
#       )
#       (1): TransitionBlock(
#         (trans): HybridSequential(
#           (0): HybridSequential(
#             (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=296)
#             (1): Conv2D(296 -> 148, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (1): Dropout(p = 0.2)
#         )
#       )
#     )
#     (3): DenseBlock(
#       (net): HybridSequential(
#         (0): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=148)
#               (1): Conv2D(148 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (1): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=160)
#               (1): Conv2D(160 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (2): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=172)
#               (1): Conv2D(172 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (3): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=184)
#               (1): Conv2D(184 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (4): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=196)
#               (1): Conv2D(196 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (5): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=208)
#               (1): Conv2D(208 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (6): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=220)
#               (1): Conv2D(220 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (7): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=232)
#               (1): Conv2D(232 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (8): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=244)
#               (1): Conv2D(244 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (9): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=256)
#               (1): Conv2D(256 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (10): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=268)
#               (1): Conv2D(268 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (11): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=280)
#               (1): Conv2D(280 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (12): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=292)
#               (1): Conv2D(292 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (13): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=304)
#               (1): Conv2D(304 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (14): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=316)
#               (1): Conv2D(316 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#         (15): BasicBlock(
#           (blk): HybridSequential(
#             (0): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=328)
#               (1): Conv2D(328 -> 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             )
#             (1): Dropout(p = 0.2)
#             (2): HybridSequential(
#               (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=48)
#               (1): Conv2D(48 -> 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             )
#             (3): Dropout(p = 0.2)
#           )
#         )
#       )
#     )
#     (4): HybridSequential(
#       (0): BatchNorm(momentum=0.9, eps=2e-05, axis=1, fix_gamma=False, in_channels=340)
#       (1): Activation(relu)
#     )
#     (5): HybridSequential(
#       (0): GlobalAvgPool2D(size=(1, 1), stride=(1, 1), padding=(0, 0), ceil_mode=True)
#       (1): Dense(340 -> 10, linear)
#     )
#   )
# )
